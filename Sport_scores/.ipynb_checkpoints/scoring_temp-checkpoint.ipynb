# %%
import pandas as pd
import numpy as np
import folium as fm

# %%
ls ../DataSets
# Out:
# Temp_score.csv*           USA_rain.csv*             wind_scores.csv*
# Temps_global.csv*         USA_wind.csv*
# USA_city_temps.csv*       madrid_monthly_means.csv*

# %%
wind = pd.read_csv("../DataSets/USA_wind.csv")
wind.head()
# Out:
#             City       Jan       Feb       Mar       Apr       May       Jun  \
# 0      Vancouver  1.930376  2.391548  2.694355  2.589722  1.994086  2.113611
# 1       Portland  2.172312  2.510047  2.327688  2.070556  1.748118  1.436944
# 2  San Francisco  2.350000  3.190603  3.139516  3.814722  3.398925  2.238611
# 3        Seattle  1.712903  2.348109  2.454570  2.310278  1.915860  1.745833
# 4    Los Angeles  1.104570  0.959515  1.257258  1.464444  1.515591  1.189444
#
#         Jul       Aug       Sep       Oct       Nov       Dec        Country  \
# 0  2.557258  2.558483  2.507363  2.423554  2.754444  2.683602         Canada
# 1  2.104301  1.695699  1.668611  1.781173  2.653014  2.409946  United States
# 2  2.827911  2.554570  2.623333  2.295684  2.327222  2.795161  United States
# 3  2.068548  1.829032  2.049444  2.141092  2.410519  2.394086  United States
# 4  1.659677  1.319086  1.256111  0.873736  1.015360  1.104032  United States
#
#     Latitude   Longitude
# ...

# %%
us_temp = pd.read_csv("../DataSets/USA_city_temps.csv")
us_temp.head()
# Out:
#    Unnamed: 0           City        Jan        Feb        Mar        Apr  \
# 0           0      Vancouver   3.435788   4.786693   7.005816   9.658979
# 1           1       Portland   3.583184   6.009428   8.547859  10.667127
# 2           2  San Francisco  10.306387  11.837995  13.281086  14.309154
# 3           3        Seattle   4.439315   5.965783   7.924323  10.183814
# 4           4    Los Angeles  12.410479  13.581205  15.487277  16.477184
#
#          May        Jun        Jul        Aug        Sep        Oct  \
# 0  13.721250  16.228408  18.976039  19.105956  15.277139  10.627567
# 1  14.565237  17.353580  20.324855  20.783623  16.835510  11.678423
# 2  15.841685  17.856091  19.471702  18.860339  18.967253  16.173920
# 3  13.941708  16.436508  18.899279  19.186526  15.686096  11.237759
# 4  17.844683  20.871611  23.275532  23.224908  22.743929  18.878352
#
#          Nov        Dec        Country   Latitude   Longitude
# ...

# %%
# For January
Jan_score=[]

for x in us_temp['Jan']:
    if x > 23.888:
        Jan_score.append(float('1'))
    elif x > 15.555:
        Jan_score.append(float('0.75'))
    elif x > 12.7: 
        Jan_score.append(float('0.5'))
    elif x > 10:
        Jan_score.append(float('0.25'))
    else:
        Jan_score.append(float('0'))
    
# For Feb
Feb_score=[]

for x in us_temp['Feb']:
    if x > 23.888:
        Feb_score.append(float('1'))
    elif x > 15.555:
        Feb_score.append(float('0.75'))
    elif x > 12.7: 
        Feb_score.append(float('0.5'))
    elif x > 10:
        Feb_score.append(float('0.25'))
    else:
        Feb_score.append(float('0'))
        
# For March
Mar_score=[]

for x in us_temp['Mar']:
    if x > 23.888:
        Mar_score.append(float('1'))
    elif x > 15.555:
        Mar_score.append(float('0.75'))
    elif x > 12.7: 
        Mar_score.append(float('0.5'))
    elif x > 10:
        Mar_score.append(float('0.25'))
    else:
        Mar_score.append(float('0'))
        
# For April
Apr_score=[]

for x in us_temp['Apr']:
    if x > 23.888:
        Apr_score.append(float('1'))
    elif x > 15.555:
        Apr_score.append(float('0.75'))
    elif x > 12.7: 
        Apr_score.append(float('0.5'))
    elif x > 10:
        Apr_score.append(float('0.25'))
    else:
        Apr_score.append(float('0'))

# For May
May_score=[]

for x in us_temp['May']:
    if x > 23.888:
        May_score.append(float('1'))
    elif x > 15.555:
        May_score.append(float('0.75'))
    elif x > 12.7: 
        May_score.append(float('0.5'))
    elif x > 10:
        May_score.append(float('0.25'))
    else:
        May_score.append(float('0'))

# For June
Jun_score=[]

for x in us_temp['Jun']:
    if x > 23.888:
        Jun_score.append(float('1'))
    elif x > 15.555:
        Jun_score.append(float('0.75'))
    elif x > 12.7: 
        Jun_score.append(float('0.5'))
    elif x > 10:
        Jun_score.append(float('0.25'))
    else:
        Jun_score.append(float('0'))

# For July
Jul_score=[]

for x in us_temp['Jul']:
    if x > 23.888:
        Jul_score.append(float('1'))
    elif x > 15.555:
        Jul_score.append(float('0.75'))
    elif x > 12.7: 
        Jul_score.append(float('0.5'))
    elif x > 10:
        Jul_score.append(float('0.25'))
    else:
        Jul_score.append(float('0'))

# For August
Aug_score=[]

for x in us_temp['Aug']:
    if x > 23.888:
        Aug_score.append(float('1'))
    elif x > 15.555:
        Aug_score.append(float('0.75'))
    elif x > 12.7: 
        Aug_score.append(float('0.5'))
    elif x > 10:
        Aug_score.append(float('0.25'))
    else:
        Aug_score.append(float('0'))

# For September
Sep_score = []

for x in us_temp['Sep']:
    if x > 23.888:
        Sep_score.append(float('1'))
    elif x > 15.555:
        Sep_score.append(float('0.75'))
    elif x > 12.7: 
        Sep_score.append(float('0.5'))
    elif x > 10:
        Sep_score.append(float('0.25'))
    else:
        Sep_score.append(float('0'))

# For October
Oct_score = []

for x in us_temp['Oct']:
    if x > 23.888:
        Oct_score.append(float('1'))
    elif x > 15.555:
        Oct_score.append(float('0.75'))
    elif x > 12.7: 
        Oct_score.append(float('0.5'))
    elif x > 10:
        Oct_score.append(float('0.25'))
    else:
        Oct_score.append(float('0'))

# For November
Nov_score = []

for x in us_temp['Nov']:
    if x > 23.888:
        Nov_score.append(float('1'))
    elif x > 15.555:
        Nov_score.append(float('0.75'))
    elif x > 12.7: 
        Nov_score.append(float('0.5'))
    elif x > 10:
        Nov_score.append(float('0.25'))
    else:
        Nov_score.append(float('0'))

# For December
Dec_score = []

for x in us_temp['Dec']:
    if x > 23.888:
        Dec_score.append(float('1'))
    elif x > 15.555:
        Dec_score.append(float('0.75'))
    elif x > 12.7: 
        Dec_score.append(float('0.5'))
    elif x > 10:
        Dec_score.append(float('0.25'))
    else:
        Dec_score.append(float('0'))

# %%
df = pd.DataFrame(columns=['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
df
# Out:
# Empty DataFrame
# Columns: [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
# Index: []

# %%
df['Jan']=Jan_score
df['Feb']=Feb_score
df['Mar']=Mar_score
df['Apr']=Apr_score
df['May']=May_score
df['Jun']=Jun_score
df['Jul']=Jul_score
df['Aug']=Aug_score
df['Sep']=Sep_score
df['Oct']=Oct_score
df['Nov']=Nov_score
df['Dec']=Dec_score

# %%
df
# Out:
#      Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 0   0.00  0.00  0.00  0.00  0.50  0.75  0.75  0.75  0.50  0.25  0.00  0.00
# 1   0.00  0.00  0.00  0.25  0.50  0.75  0.75  0.75  0.75  0.25  0.00  0.00
# 2   0.25  0.25  0.50  0.50  0.75  0.75  0.75  0.75  0.75  0.75  0.50  0.25
# 3   0.00  0.00  0.00  0.25  0.50  0.75  0.75  0.75  0.75  0.25  0.00  0.00
# 4   0.25  0.50  0.50  0.75  0.75  0.75  0.75  0.75  0.75  0.75  0.50  0.25
# 5   0.25  0.50  0.50  0.75  0.75  0.75  0.75  0.75  0.75  0.75  0.50  0.25
# 6   0.00  0.25  0.75  0.75  0.75  1.00  1.00  1.00  1.00  0.75  0.25  0.00
# 7   0.25  0.50  0.75  0.75  1.00  1.00  1.00  1.00  1.00  0.75  0.75  0.25
# 8   0.00  0.00  0.00  0.25  0.75  0.75  0.75  0.75  0.75  0.25  0.00  0.00
# 9   0.00  0.00  0.00  0.00  0.25  0.75  0.75  0.75  0.75  0.00  0.00  0.00
# 10  0.25  0.50  0.75  0.75  0.75  1.00  1.00  1.00  1.00  0.75  0.75  0.25
# ...

# %%
us_temp.head()
# Out:
#    Unnamed: 0           City        Jan        Feb        Mar        Apr  \
# 0           0      Vancouver   3.435788   4.786693   7.005816   9.658979
# 1           1       Portland   3.583184   6.009428   8.547859  10.667127
# 2           2  San Francisco  10.306387  11.837995  13.281086  14.309154
# 3           3        Seattle   4.439315   5.965783   7.924323  10.183814
# 4           4    Los Angeles  12.410479  13.581205  15.487277  16.477184
#
#          May        Jun        Jul        Aug        Sep        Oct  \
# 0  13.721250  16.228408  18.976039  19.105956  15.277139  10.627567
# 1  14.565237  17.353580  20.324855  20.783623  16.835510  11.678423
# 2  15.841685  17.856091  19.471702  18.860339  18.967253  16.173920
# 3  13.941708  16.436508  18.899279  19.186526  15.686096  11.237759
# 4  17.844683  20.871611  23.275532  23.224908  22.743929  18.878352
#
#          Nov        Dec        Country   Latitude   Longitude
# ...

# %%
dict = {"cities":us_temp.City,
        "lat":us_temp.Latitude,
       "lon":us_temp.Longitude}
use = pd.DataFrame(dict)
use.head()
# Out:
#           cities        lat         lon
# 0      Vancouver  49.249660 -123.119339
# 1       Portland  45.523449 -122.676208
# 2  San Francisco  37.774929 -122.419418
# 3        Seattle  47.606209 -122.332069
# 4    Los Angeles  34.052231 -118.243683

# %%
result = pd.concat([use, df], axis=1, join_axes=[use.index])
result
# Out:
#                cities        lat         lon   Jan   Feb   Mar   Apr   May  \
# 0           Vancouver  49.249660 -123.119339  0.00  0.00  0.00  0.00  0.50
# 1            Portland  45.523449 -122.676208  0.00  0.00  0.00  0.25  0.50
# 2       San Francisco  37.774929 -122.419418  0.25  0.25  0.50  0.50  0.75
# 3             Seattle  47.606209 -122.332069  0.00  0.00  0.00  0.25  0.50
# 4         Los Angeles  34.052231 -118.243683  0.25  0.50  0.50  0.75  0.75
# 5           San Diego  32.715328 -117.157257  0.25  0.50  0.50  0.75  0.75
# 6           Las Vegas  36.174969 -115.137222  0.00  0.25  0.75  0.75  0.75
# 7             Phoenix  33.448380 -112.074043  0.25  0.50  0.75  0.75  1.00
# 8         Albuquerque  35.084492 -106.651138  0.00  0.00  0.00  0.25  0.75
# 9              Denver  39.739151 -104.984703  0.00  0.00  0.00  0.00  0.25
# 10        San Antonio  29.424120  -98.493629  0.25  0.50  0.75  0.75  0.75
# ...

# %%
result.rename(columns={"cities": "City", "lat": "Latitude", "lon":"Longitude"})
# Out:
#                  City   Latitude   Longitude   Jan   Feb   Mar   Apr   May  \
# 0           Vancouver  49.249660 -123.119339  0.00  0.00  0.00  0.00  0.50
# 1            Portland  45.523449 -122.676208  0.00  0.00  0.00  0.25  0.50
# 2       San Francisco  37.774929 -122.419418  0.25  0.25  0.50  0.50  0.75
# 3             Seattle  47.606209 -122.332069  0.00  0.00  0.00  0.25  0.50
# 4         Los Angeles  34.052231 -118.243683  0.25  0.50  0.50  0.75  0.75
# 5           San Diego  32.715328 -117.157257  0.25  0.50  0.50  0.75  0.75
# 6           Las Vegas  36.174969 -115.137222  0.00  0.25  0.75  0.75  0.75
# 7             Phoenix  33.448380 -112.074043  0.25  0.50  0.75  0.75  1.00
# 8         Albuquerque  35.084492 -106.651138  0.00  0.00  0.00  0.25  0.75
# 9              Denver  39.739151 -104.984703  0.00  0.00  0.00  0.00  0.25
# 10        San Antonio  29.424120  -98.493629  0.25  0.50  0.75  0.75  0.75
# ...

# %%
result.to_csv("vmg-prelim/DataSets/cityTemps_scaled.csv", index=False)
