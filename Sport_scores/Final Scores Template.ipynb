# %%
import pandas as pd

# %%
cd vmg-prelim/DataSets/
# Out:
# /Users/alexandersu/Documents/Vemgoo/vmg-prelim/DataSets

# %%
df=pd.read_csv("wind_scores.csv")

# %%
df2=pd.read_csv("cityTemps_scaled.csv")

# %%
df
# Out:
#           Country   Latitude   Longitude  Jan_score  Feb_score  Mar_score  \
# 0          Canada  49.249660 -123.119339        2.0        3.0        4.0
# 1   United States  45.523449 -122.676208        3.0        3.0        3.0
# 2   United States  37.774929 -122.419418        3.0        5.0        5.0
# 3   United States  47.606209 -122.332069        2.0        3.0        3.0
# 4   United States  34.052231 -118.243683        2.0        1.0        2.0
# 5   United States  32.715328 -117.157257        2.0        2.0        2.0
# 6   United States  36.174969 -115.137222        3.0        3.0        4.0
# 7   United States  33.448380 -112.074043        2.0        2.0        2.0
# 8   United States  35.084492 -106.651138        3.0        4.0        5.0
# 9   United States  39.739151 -104.984703        3.0        5.0        5.0
# 10  United States  29.424120  -98.493629        4.0        5.0        5.0
# 11  United States  32.783058  -96.806671        5.0        6.0        6.0
# ...

# %%
df2
# Out:
#                cities        lat         lon   Jan   Feb   Mar   Apr   May  \
# 0           Vancouver  49.249660 -123.119339  0.00  0.00  0.00  0.00  0.50
# 1            Portland  45.523449 -122.676208  0.00  0.00  0.00  0.25  0.50
# 2       San Francisco  37.774929 -122.419418  0.25  0.25  0.50  0.50  0.75
# 3             Seattle  47.606209 -122.332069  0.00  0.00  0.00  0.25  0.50
# 4         Los Angeles  34.052231 -118.243683  0.25  0.50  0.50  0.75  0.75
# 5           San Diego  32.715328 -117.157257  0.25  0.50  0.50  0.75  0.75
# 6           Las Vegas  36.174969 -115.137222  0.00  0.25  0.75  0.75  0.75
# 7             Phoenix  33.448380 -112.074043  0.25  0.50  0.75  0.75  1.00
# 8         Albuquerque  35.084492 -106.651138  0.00  0.00  0.00  0.25  0.75
# 9              Denver  39.739151 -104.984703  0.00  0.00  0.00  0.00  0.25
# 10        San Antonio  29.424120  -98.493629  0.25  0.50  0.75  0.75  0.75
# ...
