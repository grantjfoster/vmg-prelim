# %%
import numpy as np
import pandas as pd

# %%
cd ../DataSets/
# Out:
# /Volumes/FOSTERFLASH/Vemgoo/vmg-prelim/DataSets

# %%
wind=pd.read_csv('USA_wind.csv')
temp=pd.read_csv('USA_city_temps.csv')
city=pd.read_csv('city_attributes.csv')
rain=pd.read_csv('USA_rain_average.csv')
city_final=pd.read_csv('city_attributes.csv')

# %%
wind
# Out:
#                  City       Jan       Feb       Mar       Apr       May  \
# 0           Vancouver  1.930376  2.391548  2.694355  2.589722  1.994086
# 1            Portland  2.172312  2.510047  2.327688  2.070556  1.748118
# 2       San Francisco  2.350000  3.190603  3.139516  3.814722  3.398925
# 3             Seattle  1.712903  2.348109  2.454570  2.310278  1.915860
# 4         Los Angeles  1.104570  0.959515  1.257258  1.464444  1.515591
# 5           San Diego  1.447581  1.746749  1.835753  2.251389  2.105914
# 6           Las Vegas  2.164336  2.248522  2.722431  3.243401  3.177294
# 7             Phoenix  1.655645  1.617317  1.748319  2.275278  2.158871
# 8         Albuquerque  2.456452  2.884752  3.233791  3.775000  3.216667
# 9              Denver  2.304301  3.267730  3.150578  3.101944  2.310484
# 10        San Antonio  2.754570  3.230496  3.371505  3.428333  3.680914
# 11             Dallas  3.400806  4.135934  4.054032  4.511944  3.992742
# ...

# %%
#scoring for wind
Jan_score=[]

for x in wind['Jan']:
    if x > 3.49:
        Jan_score.append(float('3')),    
    elif x > 3.013:
        Jan_score.append(float('2.5')),
    elif x > 2.686:
        Jan_score.append(float('2')), 
    elif x > 2.164:
        Jan_score.append(float('1.5')),
    elif x > 1.104:
        Jan_score.append(float('1')), 
    else:
        Jan_score.append(float('.5')),
city["jan_score_wind"]=Jan_score

Feb_score=[]

for x in wind['Feb']:
    if x > 3.49:
        Feb_score.append(float('3')),    
    elif x > 3.013:
        Feb_score.append(float('2.5')),
    elif x > 2.686:
        Feb_score.append(float('2')), 
    elif x > 2.164:
        Feb_score.append(float('1.5')),
    elif x > 1.104:
        Feb_score.append(float('1')), 
    else:
        Feb_score.append(float('.5')),

city["feb_score_wind"]=Feb_score

Mar_score=[]
for x in wind['Mar']:
    if x > 3.49:
        Mar_score.append(float('3')),    
    elif x > 3.013:
        Mar_score.append(float('2.5')),
    elif x > 2.686:
        Mar_score.append(float('2')), 
    elif x > 2.164:
        Mar_score.append(float('1.5')),
    elif x > 1.104:
        Mar_score.append(float('1')), 
    else:
        Mar_score.append(float('.5')),
city["mar_score_wind"]=Mar_score

Apr_score=[]
for x in wind['Apr']:
    if x > 3.49:
        Apr_score.append(float('3')),    
    elif x > 3.013:
        Apr_score.append(float('2.5')),
    elif x > 2.686:
        Apr_score.append(float('2')), 
    elif x > 2.164:
        Apr_score.append(float('1.5')),
    elif x > 1.104:
        Apr_score.append(float('1')), 
    else:
        Apr_score.append(float('.5')),
city["apr_score_wind"]=Apr_score

May_score=[]
for x in wind['May']:
    if x > 3.49:
        May_score.append(float('3')),    
    elif x > 3.013:
        May_score.append(float('2.5')),
    elif x > 2.686:
        May_score.append(float('2')), 
    elif x > 2.164:
        May_score.append(float('1.5')),
    elif x > 1.104:
        May_score.append(float('1')), 
    else:
        May_score.append(float('.5')),
city["may_score_wind"]=May_score

Jun_score=[]
for x in wind['Jun']:
    if x > 3.49:
        Jun_score.append(float('3')),    
    elif x > 3.013:
        Jun_score.append(float('2.5')),
    elif x > 2.686:
        Jun_score.append(float('2')), 
    elif x > 2.164:
        Jun_score.append(float('1.5')),
    elif x > 1.104:
        Jun_score.append(float('1')), 
    else:
        Jun_score.append(float('.5')),
city["jun_score_wind"]=Jun_score

Jul_score=[]
for x in wind['Jul']:
    if x > 3.49:
        Jul_score.append(float('3')),    
    elif x > 3.013:
        Jul_score.append(float('2.5')),
    elif x > 2.686:
        Jul_score.append(float('2')), 
    elif x > 2.164:
        Jul_score.append(float('1.5')),
    elif x > 1.104:
        Jul_score.append(float('1')), 
    else:
        Jul_score.append(float('.5')),
city["jul_score_wind"]=Jul_score

Aug_score=[]
for x in wind['Aug']:
    if x > 3.49:
        Aug_score.append(float('3')),    
    elif x > 3.013:
        Aug_score.append(float('2.5')),
    elif x > 2.686:
        Aug_score.append(float('2')), 
    elif x > 2.164:
        Aug_score.append(float('1.5')),
    elif x > 1.104:
        Aug_score.append(float('1')), 
    else:
        Aug_score.append(float('.5')),
city["aug_score_wind"]=Aug_score

Sep_score=[]
for x in wind['Sep']:
    if x > 3.49:
        Sep_score.append(float('3')),    
    elif x > 3.013:
        Sep_score.append(float('2.5')),
    elif x > 2.686:
        Sep_score.append(float('2')), 
    elif x > 2.164:
        Sep_score.append(float('1.5')),
    elif x > 1.104:
        Sep_score.append(float('1')), 
    else:
        Sep_score.append(float('.5')),
city["sep_score_wind"]=Sep_score

Oct_score=[]
for x in wind['Oct']:
    if x > 3.49:
        Oct_score.append(float('3')),    
    elif x > 3.013:
        Oct_score.append(float('2.5')),
    elif x > 2.686:
        Oct_score.append(float('2')), 
    elif x > 2.164:
        Oct_score.append(float('1.5')),
    elif x > 1.104:
        Oct_score.append(float('1')), 
    else:
        Oct_score.append(float('.5')),
city["oct_score_wind"]=Oct_score

Nov_score=[]
for x in wind['Nov']:
    if x > 3.49:
        Nov_score.append(float('3')),    
    elif x > 3.013:
        Nov_score.append(float('2.5')),
    elif x > 2.686:
        Nov_score.append(float('2')), 
    elif x > 2.164:
        Nov_score.append(float('1.5')),
    elif x > 1.104:
        Nov_score.append(float('1')), 
    else:
        Nov_score.append(float('.5')),
city["nov_score_wind"]=Nov_score


Dec_score=[]
for x in wind['Dec']:
    if x > 3.49:
        Dec_score.append(float('3')),    
    elif x > 3.013:
        Dec_score.append(float('2.5')),
    elif x > 2.686:
        Dec_score.append(float('2')), 
    elif x > 2.164:
        Dec_score.append(float('1.5')),
    elif x > 1.104:
        Dec_score.append(float('1')), 
    else:
        Dec_score.append(float('.5')),
city["dec_score_wind"]=Dec_score

# %%
#scoring for temperature
# For January
Jan_score=[]

for x in temp['Jan']:
    if x > 33:
        Jan_score.append(float('1'))
    elif x > 26.667:
        Jan_score.append(float('6'))
    elif x > 23.888:
        Jan_score.append(float('5'))
    elif x > 21.11: 
        Jan_score.append(float('4'))
    elif x > 15.55:
        Jan_score.append(float('3'))
    elif x > 12.7:
        Jan_score.append(float('2'))
    else:
        Jan_score.append(float('1'))
city["jan_score_temp"]=Jan_score    

# For Feb
Feb_score=[]

for x in temp['Feb']:
    if x > 33:
        Feb_score.append(float('1'))
    elif x > 26.667:
        Feb_score.append(float('6'))
    elif x > 23.888:
        Feb_score.append(float('5'))
    elif x > 21.11: 
        Feb_score.append(float('4'))
    elif x > 15.55:
        Feb_score.append(float('3'))
    elif x > 12.7:
        Feb_score.append(float('2'))
    else:
        Feb_score.append(float('1'))
city["feb_score_temp"]=Feb_score      

# For March
Mar_score=[]

for x in temp['Mar']:
    if x > 33:
        Mar_score.append(float('1'))
    elif x > 26.667:
        Mar_score.append(float('6'))
    elif x > 23.888:
        Mar_score.append(float('5'))
    elif x > 21.11: 
        Mar_score.append(float('4'))
    elif x > 15.55:
        Mar_score.append(float('3'))
    elif x > 12.7:
        Mar_score.append(float('2'))
    else:
        Mar_score.append(float('1'))
city["mar_score_temp"]=Mar_score        
        
# For April
Apr_score=[]

for x in temp['Apr']:
    if x > 33:
        Apr_score.append(float('1'))
    elif x > 26.667:
        Apr_score.append(float('6'))
    elif x > 23.888:
        Apr_score.append(float('5'))
    elif x > 21.11: 
        Apr_score.append(float('4'))
    elif x > 15.55:
        Apr_score.append(float('3'))
    elif x > 12.7:
        Apr_score.append(float('2'))
    else:
        Apr_score.append(float('1'))
city["apr_score_temp"]=Apr_score

# For May
May_score=[]

for x in temp['May']:
    if x > 33:
        May_score.append(float('1'))
    elif x > 26.667:
        May_score.append(float('6'))
    elif x > 23.888:
        May_score.append(float('5'))
    elif x > 21.11: 
        May_score.append(float('4'))
    elif x > 15.55:
        May_score.append(float('3'))
    elif x > 12.7:
        May_score.append(float('2'))
    else:
        May_score.append(float('1'))
city["may_score_temp"]=May_score

# For June
Jun_score=[]

for x in temp['Jun']:
    if x > 33:
        Jun_score.append(float('1'))
    elif x > 26.667:
        Jun_score.append(float('6'))
    elif x > 23.888:
        Jun_score.append(float('5'))
    elif x > 21.11: 
        Jun_score.append(float('4'))
    elif x > 15.55:
        Jun_score.append(float('3'))
    elif x > 12.7:
        Jun_score.append(float('2'))
    else:
        Jun_score.append(float('1'))
city["jun_score_temp"]=Jun_score

# For July
Jul_score=[]

for x in temp['Jul']:
    if x > 33:
        Jul_score.append(float('1'))
    elif x > 26.667:
        Jul_score.append(float('6'))
    elif x > 23.888:
        Jul_score.append(float('5'))
    elif x > 21.11: 
        Jul_score.append(float('4'))
    elif x > 15.55:
        Jul_score.append(float('3'))
    elif x > 12.7:
        Jul_score.append(float('2'))
    else:
        Jul_score.append(float('1'))
city["jul_score_temp"]=Jul_score

# For August
Aug_score=[]

for x in temp['Aug']:
    if x > 33:
        Aug_score.append(float('1'))
    elif x > 26.667:
        Aug_score.append(float('6'))
    elif x > 23.888:
        Aug_score.append(float('5'))
    elif x > 21.11: 
        Aug_score.append(float('4'))
    elif x > 15.55:
        Aug_score.append(float('3'))
    elif x > 12.7:
        Aug_score.append(float('2'))
    else:
        Aug_score.append(float('1'))
city["aug_score_temp"]=Aug_score

# For September
Sep_score = []

for x in temp['Sep']:
    if x > 33:
        Sep_score.append(float('1'))
    elif x > 26.667:
        Sep_score.append(float('6'))
    elif x > 23.888:
        Sep_score.append(float('5'))
    elif x > 21.11: 
        Sep_score.append(float('4'))
    elif x > 15.55:
        Sep_score.append(float('3'))
    elif x > 12.7:
        Sep_score.append(float('2'))
    else:
        Sep_score.append(float('1'))
city["sep_score_temp"]=Sep_score

# For October
Oct_score = []

for x in temp['Oct']:
    if x > 33:
        Oct_score.append(float('1'))
    elif x > 26.667:
        Oct_score.append(float('6'))
    elif x > 23.888:
        Oct_score.append(float('5'))
    elif x > 21.11: 
        Oct_score.append(float('4'))
    elif x > 15.55:
        Oct_score.append(float('3'))
    elif x > 12.7:
        Oct_score.append(float('2'))
    else:
        Oct_score.append(float('1'))
city["oct_score_temp"]=Oct_score

# For November
Nov_score = []

for x in temp['Nov']:
    if x > 33:
        Nov_score.append(float('1'))
    elif x > 26.667:
        Nov_score.append(float('6'))
    elif x > 23.888:
        Nov_score.append(float('5'))
    elif x > 21.11: 
        Nov_score.append(float('4'))
    elif x > 15.55:
        Nov_score.append(float('3'))
    elif x > 12.7:
        Nov_score.append(float('2'))
    else:
        Nov_score.append(float('1'))
city["nov_score_temp"]=Nov_score

# For December
Dec_score = []

for x in temp['Dec']:
    if x > 33:
        Dec_score.append(float('1'))
    elif x > 26.667:
        Dec_score.append(float('6'))
    elif x > 23.888:
        Dec_score.append(float('5'))
    elif x > 21.11: 
        Dec_score.append(float('4'))
    elif x > 15.55:
        Dec_score.append(float('3'))
    elif x > 12.7:
        Dec_score.append(float('2'))
    else:
        Dec_score.append(float('1'))
city["dec_score_temp"]=Dec_score

# %%
rain
# Out:
#                  City       Jan       Feb       Mar       Apr       May  \
# 0           Vancouver  0.269086  0.281028  0.350000  0.314167  0.221237
# 1            Portland  0.283871  0.303783  0.322312  0.340556  0.234677
# 2       San Francisco  0.128763  0.188534  0.131452  0.133889  0.137097
# 3             Seattle  0.274731  0.345449  0.365054  0.313889  0.209140
# 4         Los Angeles  0.084409  0.105496  0.066935  0.067778  0.103226
# 5           San Diego  0.085484  0.078310  0.058333  0.090000  0.153495
# 6           Las Vegas  0.070161  0.046395  0.036022  0.062222  0.057527
# 7             Phoenix  0.072849  0.034870  0.033871  0.027778  0.044624
# 8         Albuquerque  0.084140  0.059397  0.039516  0.058056  0.102151
# 9              Denver  0.145430  0.153369  0.122043  0.189722  0.303763
# 10        San Antonio  0.154839  0.107270  0.138172  0.186944  0.229570
# 11             Dallas  0.108871  0.128546  0.173118  0.201389  0.241667
# ...

# %%
city_final['Jan_total_score']=city['jan_score_temp'] + city['jan_score_wind']
city_final['Feb_total_score']=city['feb_score_temp'] + city['feb_score_wind']
city_final['Mar_total_score']=city['mar_score_temp'] + city['mar_score_wind']
city_final['Apr_total_score']=city['apr_score_temp'] + city['apr_score_wind']
city_final['May_total_score']=city['may_score_temp'] + city['may_score_wind']
city_final['Jun_total_score']=city['jun_score_temp'] + city['jun_score_wind']
city_final['Jul_total_score']=city['jul_score_temp'] + city['jul_score_wind']
city_final['Sep_total_score']=city['sep_score_temp'] + city['sep_score_wind']
city_final['Aug_total_score']=city['aug_score_temp'] + city['aug_score_wind']
city_final['Nov_total_score']=city['nov_score_temp'] + city['nov_score_wind']
city_final['Dec_total_score']=city['oct_score_temp'] + city['oct_score_wind']
city_final['Dec_total_score']=city['dec_score_temp'] + city['dec_score_wind']

# %%
city_final
# Out:
#                  City        Country   Latitude   Longitude  Jan_total_score  \
# 0           Vancouver         Canada  49.249660 -123.119339              2.0
# 1            Portland  United States  45.523449 -122.676208              2.5
# 2       San Francisco  United States  37.774929 -122.419418              2.5
# 3             Seattle  United States  47.606209 -122.332069              2.0
# 4         Los Angeles  United States  34.052231 -118.243683              2.0
# 5           San Diego  United States  32.715328 -117.157257              2.0
# 6           Las Vegas  United States  36.174969 -115.137222              2.5
# 7             Phoenix  United States  33.448380 -112.074043              2.0
# 8         Albuquerque  United States  35.084492 -106.651138              2.5
# 9              Denver  United States  39.739151 -104.984703              2.5
# 10        San Antonio  United States  29.424120  -98.493629              3.0
# ...

# %%
#convert 
#scoring for rain
Jan_score=[]

for x in rain['Jan']:
    if x > .222:
        Jan_score.append(float('.5')),    
    elif x > .184:
        Jan_score.append(float('1')),
    elif x > .149:
        Jan_score.append(float('1.5')), 
    elif x > .117:
        Jan_score.append(float('2')),
    elif x > .0622:
        Jan_score.append(float('2.5')), 
    else:
        Jan_score.append(float('3')),
city["jan_score_rain"]=Jan_score

Feb_score=[]

for x in rain['Feb']:
    if x > .222:
        Feb_score.append(float('.5')),    
    elif x > .184:
        Feb_score.append(float('1')),
    elif x > .149:
        Feb_score.append(float('1.5')), 
    elif x > .117:
        Feb_score.append(float('2')),
    elif x > .0622:
        Feb_score.append(float('2.5')), 
    else:
        Feb_score.append(float('3')),

city["feb_score_rain"]=Feb_score

Mar_score=[]
for x in rain['Mar']:
    if x > .222:
        Mar_score.append(float('.5')),    
    elif x > .184:
        Mar_score.append(float('1')),
    elif x > .149:
        Mar_score.append(float('1.5')), 
    elif x > .117:
        Mar_score.append(float('2')),
    elif x > .0622:
        Mar_score.append(float('2.5')), 
    else:
        Mar_score.append(float('3')),
city["mar_score_rain"]=Mar_score

Apr_score=[]
for x in rain['Apr']:
    if x > .222:
        Apr_score.append(float('.5')),    
    elif x > .184:
        Apr_score.append(float('1')),
    elif x > .149:
        Apr_score.append(float('1.5')), 
    elif x > .117:
        Apr_score.append(float('2')),
    elif x > .0622:
        Apr_score.append(float('2.5')), 
    else:
        Apr_score.append(float('3')),
city["apr_score_rain"]=Apr_score

May_score=[]
for x in rain['May']:
    if x > .222:
        May_score.append(float('.5')),    
    elif x > .184:
        May_score.append(float('1')),
    elif x > .149:
        May_score.append(float('1.5')), 
    elif x > .117:
        May_score.append(float('2')),
    elif x > .0622:
        May_score.append(float('2.5')), 
    else:
        May_score.append(float('3')),
city["may_score_rain"]=May_score

Jun_score=[]
for x in rain['Jun']:
    if x > .222:
        Jun_score.append(float('.5')),    
    elif x > .184:
        Jun_score.append(float('1')),
    elif x > .149:
        Jun_score.append(float('1.5')), 
    elif x > .117:
        Jun_score.append(float('2')),
    elif x > .0622:
        Jun_score.append(float('2.5')), 
    else:
        Jun_score.append(float('3')),
city["jun_score_rain"]=Jun_score

Jul_score=[]
for x in rain['Jul']:
    if x > .222:
        Jul_score.append(float('.5')),    
    elif x > .184:
        Jul_score.append(float('1')),
    elif x > .149:
        Jul_score.append(float('1.5')), 
    elif x > .117:
        Jul_score.append(float('2')),
    elif x > .0622:
        Jul_score.append(float('2.5')), 
    else:
        Jul_score.append(float('3')),
city["jul_score_rain"]=Jul_score

Aug_score=[]
for x in rain['Aug']:
    if x > .222:
        Aug_score.append(float('.5')),    
    elif x > .184:
        Aug_score.append(float('1')),
    elif x > .149:
        Aug_score.append(float('1.5')), 
    elif x > .117:
        Aug_score.append(float('2')),
    elif x > .0622:
        Aug_score.append(float('2.5')), 
    else:
        Aug_score.append(float('3')),
city["aug_score_rain"]=Aug_score

Sep_score=[]
for x in rain['Sep']:
    if x > .222:
        Sep_score.append(float('.5')),    
    elif x > .184:
        Sep_score.append(float('1')),
    elif x > .149:
        Sep_score.append(float('1.5')), 
    elif x > .117:
        Sep_score.append(float('2')),
    elif x > .0622:
        Sep_score.append(float('2.5')), 
    else:
        Sep_score.append(float('3')),
city["sep_score_rain"]=Sep_score

Oct_score=[]
for x in rain['Oct']:
    if x > .222:
        Oct_score.append(float('.5')),    
    elif x > .184:
        Oct_score.append(float('1')),
    elif x > .149:
        Oct_score.append(float('1.5')), 
    elif x > .117:
        Oct_score.append(float('2')),
    elif x > .0622:
        Oct_score.append(float('2.5')), 
    else:
        Oct_score.append(float('3')),
city["oct_score_rain"]=Oct_score

Nov_score=[]
for x in rain['Nov']:
    if x > .222:
        Nov_score.append(float('.5')),    
    elif x > .184:
        Nov_score.append(float('1')),
    elif x > .149:
        Nov_score.append(float('1.5')), 
    elif x > .117:
        Nov_score.append(float('2')),
    elif x > .0622:
        Nov_score.append(float('2.5')), 
    else:
        Nov_score.append(float('3')),
city["nov_score_rain"]=Nov_score


Dec_score=[]
for x in rain['Dec']:
    if x > .222:
        Dec_score.append(float('.5')),    
    elif x > .184:
        Dec_score.append(float('1')),
    elif x > .149:
        Dec_score.append(float('1.5')), 
    elif x > .117:
        Dec_score.append(float('2')),
    elif x > .0622:
        Dec_score.append(float('2.5')), 
    else:
        Dec_score.append(float('3')),
city["dec_score_rain"]=Dec_score

# %%
#convert cell to code 
city_final['Jan_total_score']=city['jan_score_temp'] + city['jan_score_wind']+city['jan_score_rain']
city_final['Feb_total_score']=city['feb_score_temp'] + city['feb_score_wind']+city['feb_score_rain']
city_final['Mar_total_score']=city['mar_score_temp'] + city['mar_score_wind']+city['mar_score_rain']
city_final['Apr_total_score']=city['apr_score_temp'] + city['apr_score_wind']+city['apr_score_rain']
city_final['May_total_score']=city['may_score_temp'] + city['may_score_wind']+city['may_score_rain']
city_final['Jun_total_score']=city['jun_score_temp'] + city['jun_score_wind']+city['jun_score_rain']
city_final['Jul_total_score']=city['jul_score_temp'] + city['jul_score_wind']+city['jul_score_rain']
city_final['Aug_total_score']=city['aug_score_temp'] + city['aug_score_wind']+city['aug_score_rain']
city_final['Sep_total_score']=city['sep_score_temp'] + city['sep_score_wind']+city['sep_score_rain']
city_final['Oct_total_score']=city['oct_score_temp'] + city['oct_score_wind']+city['oct_score_rain']
city_final['Nov_total_score']=city['nov_score_temp'] + city['nov_score_wind']+city['nov_score_rain']
city_final['Dec_total_score']=city['dec_score_temp'] + city['dec_score_wind']+city['dec_score_rain']

# %%
city_final
# Out:
#                  City        Country   Latitude   Longitude  Jan_total_score  \
# 0           Vancouver         Canada  49.249660 -123.119339              2.5
# 1            Portland  United States  45.523449 -122.676208              3.0
# 2       San Francisco  United States  37.774929 -122.419418              4.5
# 3             Seattle  United States  47.606209 -122.332069              2.5
# 4         Los Angeles  United States  34.052231 -118.243683              4.5
# 5           San Diego  United States  32.715328 -117.157257              4.5
# 6           Las Vegas  United States  36.174969 -115.137222              5.0
# 7             Phoenix  United States  33.448380 -112.074043              4.5
# 8         Albuquerque  United States  35.084492 -106.651138              5.0
# 9              Denver  United States  39.739151 -104.984703              4.5
# 10        San Antonio  United States  29.424120  -98.493629              4.5
# ...

# %%
city_final.to_csv("cycling_final_score.csv")
